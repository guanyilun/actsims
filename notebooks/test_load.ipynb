# %%
# %pylab inline 

from pixell import enplot, enmap
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = enmap.read_map("../outputs/test_noise.fits")

# %%
enplot.show(enplot.plot(data, downgrade=4))
# Out:
# <PIL.Image.Image image mode=RGBA size=1014x456 at 0x7F95117FDA10>
# <PIL.Image.Image image mode=RGBA size=1014x456 at 0x7F95117FD8D0>
# <PIL.Image.Image image mode=RGBA size=1014x456 at 0x7F95117FDD90>

# %%
data = enmap.read_map("../outputs/test_foregrounds.fits")
enplot.show(enplot.plot(data, downgrade=4))
# Out:
# <PIL.Image.Image image mode=RGBA size=1014x456 at 0x7F95117FD950>
# <PIL.Image.Image image mode=RGBA size=1014x456 at 0x7F95117FDC10>
# <PIL.Image.Image image mode=RGBA size=1014x456 at 0x7F95117FD910>
